# %%
import pandas as pd

# %%
df = pd.read_csv('movie_processed_data.csv')

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19925 entries, 0 to 19924
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       19925 non-null  object
#  1   type          19925 non-null  object
#  2   title         19925 non-null  object
#  3   director      15712 non-null  object
#  4   cast          19290 non-null  object
#  5   country       10569 non-null  object
#  6   date_added    10399 non-null  object
#  7   release_year  19925 non-null  int64
#  8   rating        19581 non-null  object
#  9   duration      19922 non-null  object
#  10  listed_in     19925 non-null  object
#  11  description   19925 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.8+ MB

# %%
df1 = pd.read_csv('movie_proccessed_data2.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19925 entries, 0 to 19924
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       19925 non-null  object
#  1   type          19925 non-null  object
#  2   title         19925 non-null  object
#  3   director      14736 non-null  object
#  4   cast          17677 non-null  object
#  5   country       18688 non-null  object
#  6   date_added    10399 non-null  object
#  7   release_year  19925 non-null  int64
#  8   rating        19581 non-null  object
#  9   duration      19922 non-null  object
#  10  listed_in     19925 non-null  object
#  11  description   19925 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.8+ MB

# %%
df1
# Out:
#       show_id     type                         title        director  \
# 0          s1    Movie           The Grand Seduction    Don McKellar
# 1          s2    Movie          Take Care Good Night    Girish Joshi
# 2          s3    Movie          Secrets of Deception     Josh Webber
# 3          s4    Movie            Pink: Staying True  Sonia Anderson
# 4          s5    Movie                 Monster Maker    Giles Foster
# ...       ...      ...                           ...             ...
# 19920   s1137    Movie           Planet of the Birds             NaN
# 19921   s1205  TV Show           Spider-Man (Shorts)             NaN
# 19922   s1211  TV Show     Star Wars Rebels (Shorts)             NaN
# 19923   s1260  TV Show  The Book of Once Upon a Time             NaN
# 19924   s1389    Movie           Tree Climbing Lions             NaN
#
#                                                     cast         country  \
# ...

# %%
df3 = df.merge(df1[['title', 'country']], on='title', how='left')

# %%
df3.drop('country_x',axis=1,inplace=True)

# %%
df3.to_csv('final_movie_shows.csv',index=False)
